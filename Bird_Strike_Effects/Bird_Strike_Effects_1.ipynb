# %% [markdown]
# # Begining of Second Phase
#
# * sky feature's missing values will be filled after feature engineering on date column
# * aim of this notebook is feature engineering and get rid off unwanted columns.

# %% [markdown]
# # Import Libraries

# %%
# libraries for EDA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import cufflinks as cf
#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

init_notebook_mode(connected=True)
cf.go_offline()

#To display the plots
# %matplotlib inline
from ipywidgets import interact
import plotly.io as pio

pio.renderers.default = "notebook"
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Ingest Data

# %%
df_birds = pd.read_csv("birds.csv")

df_birds.head()
# Out:
#   opid           operator       atype              remarks phase_of_flt  \
# 0  AAL  AMERICAN AIRLINES       MD-80            NO DAMAGE      Descent
# 1  USA         US AIRWAYS  FK-28-4000  2 BIRDS, NO DAMAGE.        Climb
# 2  AAL  AMERICAN AIRLINES   B-727-200                  NaN     Approach
# 3  AAL  AMERICAN AIRLINES       MD-82                  NaN        Climb
# 4  AAL  AMERICAN AIRLINES       MD-82            NO DAMAGE        Climb
#
#    ac_mass  num_engs                date time_of_day state  height  speed  \
# 0      4.0       2.0   9/30/1990 0:00:00       Night    IL  7000.0  250.0
# 1      4.0       2.0  11/29/1993 0:00:00         Day    MD    10.0  140.0
# 2      4.0       3.0   8/13/1993 0:00:00         Day    TN   400.0  140.0
# 3      4.0       2.0   10/7/1993 0:00:00         Day    VA   100.0  200.0
# 4      4.0       2.0   9/25/1993 0:00:00         Day    SC    50.0  170.0
#
#   effect         sky                species birds_seen birds_struck
# 0    NaN    No Cloud  UNKNOWN BIRD - MEDIUM        NaN            1
# 1   None    No Cloud  UNKNOWN BIRD - MEDIUM       2-10         2-10
# 2   None  Some Cloud   UNKNOWN BIRD - SMALL       2-10            1
# 3   None    Overcast   UNKNOWN BIRD - SMALL        NaN            1
# 4   None  Some Cloud   UNKNOWN BIRD - SMALL       2-10            1

# %%
df = pd.read_csv("first_phase.csv",parse_dates=["date"])
df.head()
# Out:
#   opid                  operator       atype                 remarks  \
# 0  USA                US AIRWAYS  FK-28-4000     2 BIRDS, NO DAMAGE.
# 1  AAL         AMERICAN AIRLINES   B-727-200                     NaN
# 2  AAL         AMERICAN AIRLINES       MD-82                     NaN
# 3  AAL         AMERICAN AIRLINES       MD-82               NO DAMAGE
# 4  GFT  GULFSTREAM INTL AIRLINES       BE-99  FLT 714.  TIME = 1951Z
#
#    phase_of_flt       date state  height  speed effect         sky  \
# 0         Climb 1993-11-29    MD    10.0  140.0   None    No Cloud
# 1      Approach 1993-08-13    TN   400.0  140.0   None  Some Cloud
# 2         Climb 1993-10-07    VA   100.0  200.0   None    Overcast
# 3         Climb 1993-09-25    SC    50.0  170.0   None  Some Cloud
# 4  Landing Roll 1993-09-20    FL     0.0   40.0   None  Some Cloud
#
#                  species birds_struck
# 0  UNKNOWN BIRD - MEDIUM         2-10
# 1   UNKNOWN BIRD - SMALL            1
# 2   UNKNOWN BIRD - SMALL            1
# 3   UNKNOWN BIRD - SMALL            1
# 4                  HAWKS            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13116 entries, 0 to 13115
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   opid          13116 non-null  object
#  1   operator      13116 non-null  object
#  2   atype         13116 non-null  object
#  3   remarks       10666 non-null  object
#  4   phase_of_flt  13116 non-null  object
#  5   date          13116 non-null  datetime64[ns]
#  6   state         12707 non-null  object
#  7   height        13116 non-null  float64
#  8   speed         13116 non-null  float64
#  9   effect        13116 non-null  object
#  10  sky           11754 non-null  object
#  11  species       13116 non-null  object
#  12  birds_struck  13116 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 1.3+ MB

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## date

# %% [markdown]
# * Features that I will create "season", "month_of_the_year"

# %%
df.date
# Out:
# 0       1993-11-29
# 1       1993-08-13
# 2       1993-10-07
# 3       1993-09-25
# 4       1993-09-20
#            ...
# 13111   1997-10-22
# 13112   1997-06-30
# 13113   1996-09-19
# 13114   1997-01-17
# 13115   1997-11-30
# Name: date, Length: 13116, dtype: datetime64[ns]

# %%
month_of_the_year = df.date.dt.month_name()
month_of_the_year
# Out:
# 0         November
# 1           August
# 2          October
# 3        September
# 4        September
#            ...
# 13111      October
# 13112         June
# 13113    September
# 13114      January
# 13115     November
# Name: date, Length: 13116, dtype: object

# %%
df["month_of_the_year"] = month_of_the_year

# %%
df.month_of_the_year.value_counts()
# Out:
# August       1740
# September    1734
# October      1605
# July         1328
# May          1252
# November     1075
# June          922
# April         893
# March         770
# December      659
# January       603
# February      535
# Name: month_of_the_year, dtype: int64

# %%
def seasoner(x):
    if x in ["December","January","February"]:
        return "Winter"
    elif x in ["March","April","May"]:
        return "Spring"
    elif x in ["June","July","August"]:
        return "Summer"
    else:
        return "Fall"

# %%
df.month_of_the_year.transform(lambda x : seasoner(x))
# Out:
# 0          Fall
# 1        Summer
# 2          Fall
# 3          Fall
# 4          Fall
#           ...
# 13111      Fall
# 13112    Summer
# 13113      Fall
# 13114    Winter
# 13115      Fall
# Name: month_of_the_year, Length: 13116, dtype: object

# %%
df["season"] = df.month_of_the_year.transform(lambda x : seasoner(x))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13116 entries, 0 to 13115
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   opid               13116 non-null  object
#  1   operator           13116 non-null  object
#  2   atype              13116 non-null  object
#  3   remarks            10666 non-null  object
#  4   phase_of_flt       13116 non-null  object
#  5   date               13116 non-null  datetime64[ns]
#  6   state              12707 non-null  object
#  7   height             13116 non-null  float64
#  8   speed              13116 non-null  float64
#  9   effect             13116 non-null  object
#  10  sky                11754 non-null  object
#  11  species            13116 non-null  object
#  12  birds_struck       13116 non-null  object
#  13  month_of_the_year  13116 non-null  object
#  14  season             13116 non-null  object
# dtypes: datetime64[ns](1), float64(2), object(12)
# memory usage: 1.5+ MB

# %% [markdown]
# * there is no need to keep date column so I will drop

# %% [markdown]
# ## state

# %% [markdown]
# * I will seperate  the states into regions

# %%
df.state.value_counts()
# Out:
# CA    1143
# FL    1079
# TX    1069
# NY     837
# PA     649
# IL     604
# NC     415
# TN     393
# OH     390
# NJ     368
# DC     366
# LA     342
# VA     340
# KY     340
# HI     308
# GA     275
# MI     266
# MO     253
# WA     239
# AL     211
# CT     202
# MA     199
# WI     189
# NE     170
# IN     166
# MD     154
# OR     149
# UT     139
# CO     130
# AK     126
# MN     120
# IA     115
# AR      92
# AZ      79
# SC      76
# OK      67
# NV      66
# WV      65
# MS      61
# ME      55
# NH      47
# KS      47
# RI      39
# ID      36
# NM      32
# PR      26
# ND      25
# SD      25
# MT      24
# VI      21
# VT      16
# ON      14
# DE      13
# QC      11
# BC      11
# WY       9
# AB       3
# PI       1
# Name: state, dtype: int64

# %%
abbrev_df =pd.read_html("https://abbreviations.yourdictionary.com/articles/state-abbrev.html", header=0)[0]
abbrev_df
# Out:
#         State Name USPS Abbreviation Traditional Abbreviation
# 0          Alabama                AL                     Ala.
# 1           Alaska                AK                   Alaska
# 2          Arizona                AZ                    Ariz.
# 3         Arkansas                AR                     Ark.
# 4       California                CA                   Calif.
# 5         Colorado                CO                    Colo.
# 6      Connecticut                CT                    Conn.
# 7         Delaware                DE                     Del.
# 8          Florida                FL                     Fla.
# 9          Georgia                GA                      Ga.
# 10          Hawaii                HI                   Hawaii
# 11           Idaho                ID                    Idaho
# 12        Illinois                IL                     Ill.
# 13         Indiana                IN                     Ind.
# 14            Iowa                IA                     Iowa
# 15          Kansas                KS                    Kans.
# 16        Kentucky                KY                      Ky.
# 17       Louisiana                LA                      La.
# 18           Maine                ME                    Maine
# 19        Maryland                MD                      Md.
# 20   Massachusetts                MA                    Mass.
# 21        Michigan                MI                    Mich.
# 22       Minnesota                MN                    Minn.
# 23     Mississippi                MS                    Miss.
# 24        Missouri                MO                      Mo.
# 25         Montana                MT                    Mont.
# 26        Nebraska                NE            Neb. or Nebr.
# 27          Nevada                NV                     Nev.
# 28   New Hampshire                NH                     N.H.
# 29      New Jersey                NJ                     N.J.
# 30      New Mexico                NM                   N.Mex.
# 31        New York                NY                     N.Y.
# 32  North Carolina                NC                     N.C.
# 33    North Dakota                ND                   N.Dak.
# 34            Ohio                OH                     Ohio
# 35        Oklahoma                OK                    Okla.
# 36          Oregon                OR            Ore. or Oreg.
# 37    Pennsylvania                PA                      Pa.
# 38    Rhode Island                RI                     R.I.
# 39  South Carolina                SC                     S.C.
# 40    South Dakota                SD                   S.Dak.
# 41       Tennessee                TN                    Tenn.
# 42           Texas                TX            Tex. or Texas
# 43            Utah                UT                     Utah
# 44         Vermont                VT                      Vt.
# 45        Virginia                VA                      Va.
# 46      Washington                WA                    Wash.
# 47   West Virginia                WV                    W.Va.
# 48       Wisconsin                WI            Wis. or Wisc.
# 49         Wyoming                WY                     Wyo.

# %%
def get_state_names(abbrev_df,x):
    return abbrev_df.loc[abbrev_df["USPS Abbreviation"] == x, "State Name"]

# %%
get_state_names(abbrev_df,"AL")
# Out:
# 0    Alabama
# Name: State Name, dtype: object

# %%
mask = dict(zip(abbrev_df["USPS Abbreviation"], abbrev_df["State Name"]))
mask
# Out:
# {'AL': 'Alabama',
#  'AK': 'Alaska',
#  'AZ': 'Arizona',
#  'AR': 'Arkansas',
#  'CA': 'California',
#  'CO': 'Colorado',
#  'CT': 'Connecticut',
#  'DE': 'Delaware',
#  'FL': 'Florida',
#  'GA': 'Georgia',
#  'HI': 'Hawaii',
#  'ID': 'Idaho',
#  'IL': 'Illinois',
#  'IN': 'Indiana',
#  'IA': 'Iowa',
#  'KS': 'Kansas',
#  'KY': 'Kentucky',
#  'LA': 'Louisiana',
#  'ME': 'Maine',
#  'MD': 'Maryland',
#  'MA': 'Massachusetts',
#  'MI': 'Michigan',
#  'MN': 'Minnesota',
#  'MS': 'Mississippi',
#  'MO': 'Missouri',
#  'MT': 'Montana',
#  'NE': 'Nebraska',
#  'NV': 'Nevada',
#  'NH': 'New Hampshire',
#  'NJ': 'New Jersey',
#  'NM': 'New Mexico',
#  'NY': 'New York',
#  'NC': 'North Carolina',
#  'ND': 'North Dakota',
#  'OH': 'Ohio',
#  'OK': 'Oklahoma',
#  'OR': 'Oregon',
#  'PA': 'Pennsylvania',
#  'RI': 'Rhode Island',
#  'SC': 'South Carolina',
#  'SD': 'South Dakota',
#  'TN': 'Tennessee',
#  'TX': 'Texas',
#  'UT': 'Utah',
#  'VT': 'Vermont',
#  'VA': 'Virginia',
#  'WA': 'Washington',
#  'WV': 'West Virginia',
#  'WI': 'Wisconsin',
#  'WY': 'Wyoming'}

# %%
df.state.map(mask).value_counts(dropna=False)
# Out:
# California        1143
# Florida           1079
# Texas             1069
# NaN                862
# New York           837
# Pennsylvania       649
# Illinois           604
# North Carolina     415
# Tennessee          393
# Ohio               390
# New Jersey         368
# Louisiana          342
# Virginia           340
# Kentucky           340
# Hawaii             308
# Georgia            275
# Michigan           266
# Missouri           253
# Washington         239
# Alabama            211
# Connecticut        202
# Massachusetts      199
# Wisconsin          189
# Nebraska           170
# Indiana            166
# Maryland           154
# Oregon             149
# Utah               139
# Colorado           130
# Alaska             126
# Minnesota          120
# Iowa               115
# Arkansas            92
# Arizona             79
# South Carolina      76
# Oklahoma            67
# Nevada              66
# West Virginia       65
# Mississippi         61
# Maine               55
# Kansas              47
# New Hampshire       47
# Rhode Island        39
# Idaho               36
# New Mexico          32
# North Dakota        25
# South Dakota        25
# Montana             24
# Vermont             16
# Delaware            13
# Wyoming              9
# Name: state, dtype: int64

# %%
df.state = df.state.map(mask)

# %%
You are here!

# %% [markdown]
# # Filling missing values in the sky column

# %%
df.sky.isnull().sum()
# Out:
# 1362

# %%
df.loc[df.sky.isnull(), "effect"].value_counts(dropna=False)
# Out:
# None                     957
# Precautionary Landing    188
# Aborted Take-off         116
# Other                     77
# Engine Shut Down          24
# Name: effect, dtype: int64

# %%
modes = df.groupby(["month_of_the_year"]).sky.agg(pd.Series.mode)
modes
# Out:
# month_of_the_year
# April          No Cloud
# August       Some Cloud
# December       No Cloud
# February       No Cloud
# January        No Cloud
# July         Some Cloud
# June           No Cloud
# March          No Cloud
# May            No Cloud
# November       No Cloud
# October        No Cloud
# September      No Cloud
# Name: sky, dtype: object

# %%
df.loc[df.sky.isnull()]
# Out:
#       opid                        operator         atype  \
# 7      MTR                     METROFLIGHT  BA-31 JETSTR
# 9      MTR                     METROFLIGHT  BA-31 JETSTR
# 17     ABX  ABX AIR (was AIRBORNE EXPRESS)       DC-9-30
# 19     DAL                 DELTA AIR LINES         B-767
# 43     UAL                 UNITED AIRLINES         B-737
# ...    ...                             ...           ...
# 13085  FDX                   FEDEX EXPRESS         B-727
# 13090  DAL                 DELTA AIR LINES     B-737-300
# 13099  NWA              NORTHWEST AIRLINES         A-320
# 13104  UNK                         UNKNOWN         C-152
# 13115  PVT                 PRIVATELY OWNED  EXPERIMENTAL
#
#                                                  remarks  phase_of_flt  \
# 7                          NO DAMAGE REPTD. TIME = 0042Z      Approach
# 9      FLT 759 HIT BIRD OVER THRESHOLD OF RWY. FLT LA...      Approach
# 17     STRIKE JUST ABOVE F/O'S WINDOW. INSPCTN FOUND ...  Landing Roll
# 19                    FLT 1424. DAMAGE TO A/C NOT REPTD.  Landing Roll
# 43     FLT 1438. TIME = 1347Z. HIT A BIRD ON DEPTR. N...         Climb
# ...                                                  ...           ...
# 13085  FED EX 2289 STRUCK A BIRD. NO REPTD DAMGE. FLT...  Landing Roll
# 13090  FLT 977 SLC-SJC RETD W/O INCID AFTER REPORTING...         Climb
# 13099  FLT 368 ABTD T/O & RETD TO GATE DUE TO A BIRD ...  Take-off run
# 13104  DARK, MOONLESS NIGHT. DOING TOUCH & GO'S & DID...  Landing Roll
# 13115  I LOOKED UP JUST INTIME TO SEE A BIRD ABOUT 50...      En Route
#
#             date state  height  speed                 effect  sky  \
# 7     1992-02-29    TX  3000.0  135.0                   None  NaN
# 9     1992-08-19    AR   300.0  135.0                   None  NaN
# 17    1993-07-30    MS     0.0  105.0                   None  NaN
# 19    1994-07-22    UT     0.0  105.0                   None  NaN
# 43    1993-10-14    WA   200.0  150.0                   None  NaN
# ...          ...   ...     ...    ...                    ...  ...
# 13085 1998-07-10    TX     0.0  105.0                   None  NaN
# 13090 1998-07-15    UT   200.0  150.0  Precautionary Landing  NaN
# 13099 1998-03-03    MI     0.0  120.0       Aborted Take-off  NaN
# 13104 1997-05-01    NC     0.0  105.0       Engine Shut Down  NaN
# 13115 1997-11-30   NaN  2500.0  150.0  Precautionary Landing  NaN
#
#                  species birds_struck month_of_the_year  season
# 7           UNKNOWN BIRD            1          February  Winter
# 9             BLACKBIRDS            1            August  Summer
# 17          UNKNOWN BIRD            1              July  Summer
# 19          UNKNOWN BIRD            1              July  Summer
# 43          UNKNOWN BIRD            1           October    Fall
# ...                  ...          ...               ...     ...
# 13085       UNKNOWN BIRD            1              July  Summer
# 13090       UNKNOWN BIRD            1              July  Summer
# 13099       UNKNOWN BIRD            1             March  Spring
# 13104  WHITE-TAILED DEER            1               May  Spring
# 13115              DUCKS            1          November    Fall
#
# [1362 rows x 15 columns]

# %%
[modes[i] for i in df.loc[df.sky.isnull()].month_of_the_year]
# Out:
# ['No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  'Some Cloud',
#  'No Cloud',
#  'No Cloud',
#  ...]

# %%
df.loc[df.sky.isnull(),"sky"] = [modes[i] for i in df.loc[df.sky.isnull()].month_of_the_year]

# %%
df.isnull().sum()
# Out:
# opid                    0
# operator                0
# atype                   0
# remarks              2450
# phase_of_flt            0
# date                    0
# state                 409
# height                  0
# speed                   0
# effect                  0
# sky                     0
# species                 0
# birds_struck            0
# month_of_the_year       0
# season                  0
# dtype: int64
