# %%
import pyforest
import plotly
import cufflinks as cf
#Enabling the offline mode for interactive plotting locally
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
#To display the plots
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore');
from sklearn.preprocessing import MinMaxScaler,StandardScaler,RobustScaler,OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.model_selection import cross_validate, GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score, precision_recall_fscore_support
from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report,confusion_matrix,plot_confusion_matrix
from sklearn.metrics import roc_curve, auc
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %% [markdown]
# # Ingest Data

# %%
df = pd.read_csv("ready_for_preprocessing.csv")
df.head()
# Out:
#         atype  phase_of_flt               state  height  speed effect  \
# 0  FK-28-4000         Climb      South Atlantic    10.0  140.0   None
# 1   B-727-200      Approach  East South Central   400.0  140.0   None
# 2       MD-82         Climb      South Atlantic   100.0  200.0   None
# 3       MD-82         Climb      South Atlantic    50.0  170.0   None
# 4       BE-99  Landing Roll      South Atlantic     0.0   40.0   None
#
#           sky                species birds_struck month_of_the_year  season
# 0    No Cloud  UNKNOWN BIRD - MEDIUM         2-10          November    Fall
# 1  Some Cloud   UNKNOWN BIRD - SMALL            1            August  Summer
# 2    Overcast   UNKNOWN BIRD - SMALL            1           October    Fall
# 3  Some Cloud   UNKNOWN BIRD - SMALL            1         September    Fall
# 4  Some Cloud                  HAWKS            1         September    Fall

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13116 entries, 0 to 13115
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   atype              13116 non-null  object
#  1   phase_of_flt       13116 non-null  object
#  2   state              13116 non-null  object
#  3   height             13116 non-null  float64
#  4   speed              13116 non-null  float64
#  5   effect             13116 non-null  object
#  6   sky                13116 non-null  object
#  7   species            13116 non-null  object
#  8   birds_struck       13116 non-null  object
#  9   month_of_the_year  13116 non-null  object
#  10  season             13116 non-null  object
# dtypes: float64(2), object(9)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (13116, 11)

# %% [markdown]
# ## Drop duplicates
# * just droped duplicates that have "None" on target column

# %%
df.duplicated().sum()
# Out:
# 123

# %%
df.loc[df.duplicated()]["effect"].value_counts()
# Out:
# None                     120
# Precautionary Landing      3
# Name: effect, dtype: int64

# %%
drop_idx = df.loc[(df.duplicated()) & (df.effect == "None")].drop_duplicates().index

# %%
df.drop(drop_idx, inplace=True)

# %%
df.shape
# Out:
# (13038, 11)

# %%
df.reset_index(drop=True,inplace=True)
df
# Out:
#                 atype  phase_of_flt               state  height  speed  \
# 0          FK-28-4000         Climb      South Atlantic    10.0  140.0
# 1           B-727-200      Approach  East South Central   400.0  140.0
# 2               MD-82         Climb      South Atlantic   100.0  200.0
# 3               MD-82         Climb      South Atlantic    50.0  170.0
# 4               BE-99  Landing Roll      South Atlantic     0.0   40.0
# ...               ...           ...                 ...     ...    ...
# 13033           C-152         Climb      South Atlantic    50.0   65.0
# 13034  PA-38 TOMAHAWK  Take-off run      South Atlantic     0.0  120.0
# 13035           MD-80      Approach  East North Central    50.0  140.0
# 13036    LOCKHEED 188         Climb         New England    50.0  150.0
# 13037    EXPERIMENTAL      En Route             Unknown  2500.0  150.0
#
#                       effect         sky                species birds_struck  \
# ...

# %%
df[df.select_dtypes("object").columns] = df[df.select_dtypes("object").columns].astype("category")

# %%
df.height.max(), df.speed.max()
# Out:
# (32500.0, 400.0)

# %%
df[df.select_dtypes("float64").columns] = df[df.select_dtypes("float64").columns].astype("int32")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13038 entries, 0 to 13037
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   atype              13038 non-null  category
#  1   phase_of_flt       13038 non-null  category
#  2   state              13038 non-null  category
#  3   height             13038 non-null  int32
#  4   speed              13038 non-null  int32
#  5   effect             13038 non-null  category
#  6   sky                13038 non-null  category
#  7   species            13038 non-null  category
#  8   birds_struck       13038 non-null  category
#  9   month_of_the_year  13038 non-null  category
#  10  season             13038 non-null  category
# dtypes: category(9), int32(2)
# memory usage: 259.7 KB

# %%
# conda install -c conda-forge sweetviz
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\madcat\anaconda3
#
#   added / updated specs:
#     - sweetviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.9.14  |       h5b45459_0         189 KB  conda-forge
#     certifi-2022.9.14          |     pyhd8ed1ab_0         156 KB  conda-forge
#     sweetviz-2.1.4             |     pyhd8ed1ab_0        13.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   sweetviz           conda-forge/noarch::sweetviz-2.1.4-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.07.19~ --> conda-forge::ca-certificates-2022.9.14-h5b45459_0
# ...

# %%
import sweetviz as sv

my_report = sv.analyze(df)
my_report.show_notebook() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |                                             | [  0%]   00:00 ->…
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# # Data Processing

# %%
X = df.drop("effect",axis=1)
y = df.effect

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.20, random_state=42)

# %%
my_report = sv.compare(X_train,X_test)
my_report.show_notebook()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %%
std_scaler = StandardScaler()  # will use in pipeline
min_max_scaler = MinMaxScaler()
cat = X_train.select_dtypes("category").columns
onehot_transformer = ColumnTransformer(
    [("encoder", OneHotEncoder(handle_unknown="ignore"), cat)],
    remainder=min_max_scaler)

ordinal_transformer = ColumnTransformer(
    [("encoder",OrdinalEncoder(handle_unknown="use_encoded_value", unknown_value=-1), cat)],
    remainder="passthrough")

# %% [markdown]
# # Modelling

# %% [markdown]
# ## Logistic Regression

# %%
log_pipe = Pipeline([("transformer", onehot_transformer),
                     ("log_model", LogisticRegression(class_weight="balanced"))])

# %%
log_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder=MinMaxScaler(),
#                                    transformers=[('encoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   Index(['atype', 'phase_of_flt', 'state', 'sky', 'species', 'birds_struck',
#        'month_of_the_year', 'season'],
#       dtype='object'))])),
#                 ('log_model', LogisticRegression(class_weight='balanced'))])

# %%
ypred = log_pipe.predict(X_test)
ypred_train = log_pipe.predict(X_train)

# %%
print(
    f"test  : {precision_recall_fscore_support(y_test,ypred, average='macro', labels=['Engine Shut Down'])}"
)
print(
    f"train : {precision_recall_fscore_support(y_train,ypred_train,average='macro', labels=['Engine Shut Down'])}"
)
# Out:
# test  : (0.03067484662576687, 0.21739130434782608, 0.053763440860215055, None)
# train : (0.11094890510948906, 0.8172043010752689, 0.19537275064267354, None)

# %%
print(confusion_matrix(y_test, ypred))
print(classification_report(y_test, ypred))
print("*-" * 30)
print(confusion_matrix(y_train, ypred_train))
print(classification_report(y_train, ypred_train))
# Out:
# [[  90    5    6    0    8]
#  [   6    5    1    4    7]
#  [ 208  123 1363  289  236]
#  [   6   10   14   25   12]
#  [  36   20   21   13  100]]
#                        precision    recall  f1-score   support
#
#      Aborted Take-off       0.26      0.83      0.40       109
#      Engine Shut Down       0.03      0.22      0.05        23
#                  None       0.97      0.61      0.75      2219
#                 Other       0.08      0.37      0.13        67
# Precautionary Landing       0.28      0.53      0.36       190
#
#              accuracy                           0.61      2608
#             macro avg       0.32      0.51      0.34      2608
#          weighted avg       0.86      0.61      0.69      2608
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# [[ 398   18    9    4    6]
#  [   6   76    2    4    5]
#  [ 774  501 5467 1134 1001]
#  [  10   12   35  180   29]
#  [  97   78   42   50  492]]
# ...

# %%
log_coefs = pd.DataFrame(log_pipe["log_model"].coef_, 
                         columns=log_pipe["transformer"].get_feature_names_out(), 
                         index = ["Aborted Take-off", "Engine Shut Down", "None", "Other", "Precautionary Landing"])
log_coefs
# Out:
#                        encoder__atype_A-300  encoder__atype_A-310  \
# Aborted Take-off                  -1.420514             -0.094885
# Engine Shut Down                   1.411281              2.020089
# None                               1.156420             -0.165445
# Other                             -0.947692             -1.142289
# Precautionary Landing             -0.199495             -0.617470
#
#                        encoder__atype_A-320  encoder__atype_AEROS 350  \
# Aborted Take-off                   0.604647                 -0.017164
# Engine Shut Down                  -1.441079                 -0.217666
# None                               0.896232                 -0.715114
# Other                              0.362759                  1.633056
# Precautionary Landing             -0.422558                 -0.683112
#
#                        encoder__atype_AEROS 355  encoder__atype_AEROS SA365  \
# ...

# %%
print(log_coefs.loc["Engine Shut Down"].sort_values().head(10))
print(log_coefs.loc["Engine Shut Down"].sort_values().tail(10))
# Out:
# encoder__atype_SAAB-340              -1.985217
# encoder__atype_C-172                 -1.935119
# encoder__atype_B-737-400             -1.796373
# encoder__atype_EMB-120               -1.783648
# encoder__species_EUROPEAN STARLING   -1.778389
# encoder__species_RED-TAILED HAWK     -1.686229
# encoder__species_LAUGHING GULL       -1.615235
# encoder__species_SPARROWS            -1.614539
# encoder__species_EGRETS              -1.471270
# encoder__atype_DHC8 DASH 8           -1.470318
# Name: Engine Shut Down, dtype: float64
# encoder__atype_LOCKHD 1329        2.342646
# encoder__atype_GULFSTRM II        2.406106
# encoder__atype_C-441 CONQUE       2.601811
# encoder__atype_DA-20 FALCON       2.641118
# encoder__atype_LOCKHEED 382       2.756675
# encoder__atype_BA-125-700         2.814821
# encoder__atype_BA-146             3.072360
# encoder__species_AMERICAN COOT    3.818747
# encoder__species_AMERICAN CROW    3.866495
# encoder__atype_PA-46 MALIBU       3.915296
# ...

# %% [markdown]
# * Vanilla log model with class balanced does not yield wanted results on Engine Shut Down class

# %% [markdown]
# ## Decision Tree

# %%
dt_pipe = Pipeline([("transformer", ordinal_transformer),
                     ("dt_model", DecisionTreeClassifier(max_depth=10, class_weight="balanced"))])

# %%
dt_pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('encoder',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   Index(['atype', 'phase_of_flt', 'state', 'sky', 'species', 'birds_struck',
#        'month_of_the_year', 'season'],
#       dtype='object'))])),
#                 ('dt_model',
#                  DecisionTreeClassifier(class_weight='balanced',
#                                         max_depth=10))])

# %%
ypred = dt_pipe.predict(X_test)
ypred_train = dt_pipe.predict(X_train)

# %%
print(confusion_matrix(y_test, ypred))
print(classification_report(y_test, ypred))
print("*-" * 30)
print(confusion_matrix(y_train, ypred_train))
print(classification_report(y_train, ypred_train))
# Out:
# [[  73    6   13    3   14]
#  [   3    2    4    1   13]
#  [ 179  120 1202  315  403]
#  [   6    6   21   17   17]
#  [  28   34   23   16   89]]
#                        precision    recall  f1-score   support
#
#      Aborted Take-off       0.25      0.67      0.37       109
#      Engine Shut Down       0.01      0.09      0.02        23
#                  None       0.95      0.54      0.69      2219
#                 Other       0.05      0.25      0.08        67
# Precautionary Landing       0.17      0.47      0.25       190
#
#              accuracy                           0.53      2608
#             macro avg       0.29      0.40      0.28      2608
#          weighted avg       0.83      0.53      0.62      2608
#
# *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# [[ 410   12    2    1   10]
#  [   0   87    0    3    3]
#  [ 706  480 4835 1335 1521]
#  [   5   14   12  214   21]
#  [  53  108   12   35  551]]
# ...

# %%
ax = pd.Series(dt_pipe["dt_model"].feature_importances_, index=['atype', 'phase_of_flt', 'state', 'sky', 'species',
       'birds_struck', 'month_of_the_year', 'season','height', 'speed']).plot.barh(figsize=(12,3))
ax.bar_label(ax.containers[0]);

# %% [markdown]
# * Vanilla DT model with balanced class weights overfitted.
# * Max dept manually reduced to 10, and still does not come up with decent outputs for target class
